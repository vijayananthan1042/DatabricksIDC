# %% [markdown]
# ### Day0 - Databricks account setup and Data loading
#
# 1. Created Databricks Free edition account.
# 2. Created Schema and Volume under the workpace catalog
# 3. Downloaded data directly from Kaggle into the volumes
# 4. Uploaded data directly from Local to the volumes
# 5. Uploaded data directly from Local and created managed tables
# 6. Executed few basic commands on the dataset like creating df, checking the df schema, checking the number of rows present in the dataset

# %%
spark.sql('''
          CREATE SCHEMA IF NOT EXISTS workspace.ecommerce
          ''')

# %%
spark.sql('''
          CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data
          ''')

# %%
# !pip install kaggle

# %%
# %sh
kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store

# %%
ls

# %%
# %sh
unzip -o ecommerce-behavior-data-from-multi-category-store.zip

# %%
rm -f ecommerce-behavior-data-from-multi-category-store.zip

# %%
ls -lh

# %%
df_nov = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv",header=True)
df_oct = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv",header=True)

# %%
print("###################October###################")
df_oct.show(5)
print("###################November###################")
df_nov.show(5)

# %%
nov_count = df_nov.count()
print("November count: ",nov_count)
oct_count = df_oct.count()
print("October count: ",oct_count)

# %%
df_nov.printSchema()

# %%
spark.sql('''
          CREATE SCHEMA IF NOT EXISTS workspace.ecommercenew
          ''')

# %%
spark.sql('''
          CREATE VOLUME IF NOT EXISTS workspace.ecommercenew.ecommerce_datanew
          ''')

# %%
cd /Volumes/workspace/ecommercenew/ecommerce_datanew

# %%
# %sh
unzip -o 2019-Nov.csv.zip

# %%
# %sh
unzip -o 2019-Oct.csv.zip

# %%
rm -f *.zip

# %%
ls

# %%
df_nov = spark.read \
        .option("header",True) \
        .csv("/Volumes/workspace/ecommercenew/ecommerce_datanew/2019-Nov.csv")
df_oct = spark.read \
        .option("header",True) \
        .csv("/Volumes/workspace/ecommercenew/ecommerce_datanew/2019-Oct.csv") 

nov_count = df_nov.count()
print("November count: ",nov_count)
oct_count = df_oct.count()
print("October count: ",oct_count)

# %%
row_count = spark.sql('SELECT count(*) as row_count FROM workspace.ecommercenew1.electronicstore').first().row_count
print("Row count: ",row_count)

# %%
df_electronics = spark.table("workspace.ecommercenew1.electronicstore")
print("Electonics store Count: ",df_electronics.count())
